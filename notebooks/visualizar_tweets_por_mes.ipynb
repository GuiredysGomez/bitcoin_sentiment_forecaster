# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el CSV
df = pd.read_csv("../data/tweets_with_sentiment_cryptobert.csv")
# Asegurarse de que la columna de fecha esté en formato datetime
df['Created At'] = pd.to_datetime(df['Created At'], errors='coerce')
# Out:
# C:\Users\toyot\AppData\Local\Temp\ipykernel_16544\4249521700.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Created At'] = pd.to_datetime(df['Created At'], errors='coerce')

# %% [markdown]
# Lectura de archivos

# %%
# Crear una columna con el año y mes (formato AAAA-MM)
df['año_mes'] = df['Created At'].dt.to_period('M').astype(str)

# Contar tweets por mes
tweets_por_mes = df['año_mes'].value_counts().sort_index()
# Out:
# C:\Users\toyot\AppData\Local\Temp\ipykernel_16544\1227643566.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['año_mes'] = df['Created At'].dt.to_period('M').astype(str)

# %% [markdown]
# Graficar

# %%
tweets_por_mes.plot(kind='bar', figsize=(12, 6), color='mediumseagreen')
plt.title('Cantidad de tweets por mes')
plt.xlabel('Mes')
plt.ylabel('Número de tweets')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Muestra los índices de los tweets con fecha NaT
print(df[df['Created At'].isna()].index)

print(df.loc[16614])
df = df.drop(5)
# Out:
# Index([16614], dtype='int64')
# Tweet_count                                                    1
# Username                                               Willy Woo
# Text           Bitcoin is once again near all time highs. The...
# Created At                                                   NaT
# Retweets                                                     NaN
# Likes                                                        NaN
# Sentiment                                                      1
# año_mes                                                      NaT
# Name: 16614, dtype: object
